# %% [markdown]
# ### Exercise 6: Histogram Customization

# %%
# TASK: Create a histogram for the following data: data = [1, 2, 2, 3, 3, 3, 4, 4, 4, 4, 5].
# Customize the histogram with a title, labels for the x-axis, and a specific color for the bars.

# %%
import matplotlib.pyplot as plt

# Data
data = [1, 2, 2, 3, 3, 3, 4, 4, 4, 4, 5]

# Create histogram
plt.hist(data, bins=range(1, 7), color='skyblue', edgecolor='black', align='left')

# Customizations
plt.title('Histogram of Data')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.xticks(range(1, 6))  # Ensure proper labeling on x-axis

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Given data
data = [1, 2, 2, 3, 3, 3, 4, 4, 4, 4, 5]

# Create the histogram
plt.hist(data, bins=range(1, 7), color='skyblue', edgecolor='black')

# Customize the plot with a title and labels
plt.title('Histogram of Data')
plt.xlabel('Value')
plt.ylabel('Frequency')

# Show the plot
plt.show()
